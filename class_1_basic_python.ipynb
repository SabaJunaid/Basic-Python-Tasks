# %% [markdown]
# ## variable

# %%
a=10
print(a)
# Out:
# 10

# %%
a=34
b=12
c=1
d=4

# %%
A=34

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# output variable

# %%
print(a)
# Out:
# 34

# %%
type(a)
# Out:
# int

# %%
print(a+b)
# Out:
# 46

# %% [markdown]
# C++

# %%
#include <iostream>
using namespace std;

int main() {
    cout << "Hello World";
    return 0;
}

# %% [markdown]
# JAVA

# %%
public class Main {
    public static void main(String[] args) {
        System.out.println("Hello World");
    }
}

# %%
x=5 # xyamkldbfdb
print(x)
# Syntax	Rules of writing code	print("Hi") (correct format)
# Statement	One complete instruction	x = 5
# Out:
# 5

# %% [markdown]
# casting

# %%
x = str(3)
y = int(3)
z = float(3)
print(x)
print(y)
print(z)
type(x)
# Out:
# 3
# 3
# 3.0
# str

# %%
x=str(10)
print(x)
type(x)
# Out:
# 10
# str

# %%
name='saba'
print(name)
type(name)
# Out:
# saba
# str

# %% [markdown]
# Allowed variable names

# %%
# myvar = "John"
# my_var = "John"
# _my_var = "John"
# myVar = "John"
# MYVAR = "John"
# myvar2 = "John"

# %% [markdown]
# illegal variables

# %%
# 2myvar = "John"
# my-var = "John"
# # my var = "John"

# %% [markdown]
# camel case

# %%
myVariableName = "John"

# %% [markdown]
# pascal case

# %%
MyVariableName = "John"

# %% [markdown]
# Assigning multiples values

# %%
x, y, z= 'orange', 'banana', 'grapes'
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# grapes

# %%
x= y=z= 'orange'
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
x=y='orange'
print(x)
print(y)
# Out:
# orange
# orange

# %% [markdown]
# Data types

# %%
# Integer any number positive or negative
# float any number with decimal
# string any alphabetical character
# complex mix of number and alphabtes e.g, 3i

# %% [markdown]
# data types in python

# %%
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
None Type:	NoneType

# %%
list=['apple', 'grapes', 'banana', 'kiwi', 'watermelon']
print(list)
# Out:
# ['apple', 'grapes', 'banana', 'kiwi', 'watermelon']

# %%
len(list) # length=len
# Out:
# 5

# %%
students=['Ayesha', 'tahreem', "muneeba", 'muneeba']
print(students)
len(students)
# Out:
# ['Ayesha', 'tahreem', 'muneeba', 'muneeba']
# 4

# %%
type(students)
# Out:
# list

# %%
# string '', "",

# %%
print("It's alright")
print("He is called 'Johnny'")
print('He is called "Johnny"')
# Out:
# It's alright
# He is called 'Johnny'
# He is called "Johnny"

# %% [markdown]
# indexing
# index start with 0

# %%
a='hello world'
print(a)
# Out:
# hello world

# %% [markdown]
# index

# %%
a='hello world'
print(a[1])
print(a[3])
# Out:
# e
# l

# %% [markdown]
# Slicing on string

# %%
a='hello world'
print(a[3:7])
# Out:
# lo w

# %% [markdown]
# positive indexing

# %%
Character	Index
H	0
e	1
l	2
l	3
o	4
(space)	5
W	6
o	7
r	8
l	9
d	10

# %% [markdown]
# negative indexing

# %%
Character	Negative Index
a='hello world'
d	-1
l	-2
r	-3
o	-4
W	-5
(space)	-6
o	-7
l	-8
l	-9
e	-10
H	-11

# %%
a='hello world'
print(a[-10])
# Out:
# e

# %%
len(a)
# Out:
# 11

# %%
students=['Ayesha', 'tahreem', "muneeba"]
print(students)
print(students[0])
len(students)
# Out:
# ['Ayesha', 'tahreem', 'muneeba']
# Ayesha
# 3

# %% [markdown]
# **Slicing** on list

# %%
print(students[0:2])
# Out:
# ['Ayesha', 'tahreem']
